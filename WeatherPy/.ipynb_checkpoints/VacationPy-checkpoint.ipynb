# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from config import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_data_df = pd.read_csv("../output_data/city_data_df.csv")
city_data_df
# Out:
#      Unnamed: 0         City      Lat       Lng  Max Temp  Humidity  \
# 0             0       kodiak  57.7900 -152.4072    288.88        59
# 1             1  puebloviejo  10.9938  -74.2844    298.28        77
# 2             2    busselton -33.6500  115.3333    289.30        69
# 3             3   san andres  12.5847  -81.7006    300.16        89
# 4             4        bytow  54.1706   17.4919    287.15        74
# ..          ...          ...      ...       ...       ...       ...
# 580         580      salalah  17.0151   54.0924    306.20        66
# 581         581    bundaberg -24.8500  152.3500    291.05        64
# 582         582       aykhal  66.0000  111.5000    292.54        26
# 583         583      osoyoos  49.0331 -119.4524    288.57        94
# 584         584     am timan  11.0297   20.2827    299.88        60
#
#      Cloudiness  Wind Speed Country        Date
# 0             0        3.60      US  1655103142
# 1            32        2.26      CO  1655103143
# 2            85        7.05      AU  1655103145
# 3            75        2.57      CO  1655103147
# 4            19        3.34      PL  1655103148
# ..          ...         ...     ...         ...
# 580          75        6.69      OM  1655103976
# 581           0        2.80      AU  1655103977
# 582           6        5.59      RU  1655103979
# 583         100        2.36      CA  1655103980
# 584         100        3.82      TD  1655103981
#
# [585 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# create lists for heatmap
humidity = city_data_df["Humidity"]
city_loc = city_data_df[["Lat","Lng"]]

# create heatmap layer on gmap fig
fig = gmaps.figure(center = [0,0] ,zoom_level = 2)
heat_layer = gmaps.heatmap_layer(city_loc, weights=humidity,
                                dissipating=False, max_intensity=100, 
                                point_radius = 2)
# add layer
fig.add_layer(heat_layer)

# check it exists
print(fig)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# create df with desired weather conditions and drop null values
clean_city_df  = city_data_df.loc[(city_data_df["Max Temp"]>70)
                            &(city_data_df["Max Temp"]<80)
                            &(city_data_df["Wind Speed"]<10)
                            &city_data_df["Cloudiness"]==0,:].dropna()

clean_city_df
# Out:
#      Unnamed: 0         City      Lat       Lng  Max Temp  Humidity  \
# 0             0       kodiak  57.7900 -152.4072    288.88        59
# 1             1  puebloviejo  10.9938  -74.2844    298.28        77
# 2             2    busselton -33.6500  115.3333    289.30        69
# 3             3   san andres  12.5847  -81.7006    300.16        89
# 4             4        bytow  54.1706   17.4919    287.15        74
# ..          ...          ...      ...       ...       ...       ...
# 580         580      salalah  17.0151   54.0924    306.20        66
# 581         581    bundaberg -24.8500  152.3500    291.05        64
# 582         582       aykhal  66.0000  111.5000    292.54        26
# 583         583      osoyoos  49.0331 -119.4524    288.57        94
# 584         584     am timan  11.0297   20.2827    299.88        60
#
#      Cloudiness  Wind Speed Country        Date
# 0             0        3.60      US  1655103142
# 1            32        2.26      CO  1655103143
# 2            85        7.05      AU  1655103145
# 3            75        2.57      CO  1655103147
# 4            19        3.34      PL  1655103148
# ..          ...         ...     ...         ...
# 580          75        6.69      OM  1655103976
# 581           0        2.80      AU  1655103977
# 582           6        5.59      RU  1655103979
# 583         100        2.36      CA  1655103980
# 584         100        3.82      TD  1655103981
#
# [583 rows x 10 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df= clean_city_df[["City", "Country", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#             City Country      Lat       Lng Hotel Name
# 0         kodiak      US  57.7900 -152.4072
# 1    puebloviejo      CO  10.9938  -74.2844
# 2      busselton      AU -33.6500  115.3333
# 3     san andres      CO  12.5847  -81.7006
# 4          bytow      PL  54.1706   17.4919
# ..           ...     ...      ...       ...        ...
# 580      salalah      OM  17.0151   54.0924
# 581    bundaberg      AU -24.8500  152.3500
# 582       aykhal      RU  66.0000  111.5000
# 583      osoyoos      CA  49.0331 -119.4524
# 584     am timan      TD  11.0297   20.2827
#
# [583 rows x 5 columns]

# %%
# create base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# set parameters for url search
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key}

# Iterate through cities
for index, row in hotel_df.iterrows():
    # get lat, lng from dataframe
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
    # Make request
    print(f"Retrieving results for city: {row['City']}")
    hotel_name = requests.get(base_url, params=params).json()
    
    # hotel_name = hotel_name['results']
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_name["results"][0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
    
    print("------------")

# Display hotel names on dataframe
hotel_df
# Out:
# Retrieving results for city: kodiak
# ------------
# Retrieving results for city: puebloviejo
# ------------
# Retrieving results for city: busselton
# ------------
# Retrieving results for city: san andres
# ------------
# Retrieving results for city: bytow
# ------------
# Retrieving results for city: puerto ayora
# ------------
# Retrieving results for city: rosetown
# ------------
# Retrieving results for city: inverell
# ------------
# Retrieving results for city: bethel
# ------------
# Retrieving results for city: nikolskoye
# ------------
# Retrieving results for city: bredasdorp
# ------------
# Retrieving results for city: bluff
# ------------
# Retrieving results for city: dunda
# Missing field/result... skipping.
# ------------
# Retrieving results for city: atuona
# ------------
# Retrieving results for city: hofn
# ------------
# Retrieving results for city: mataura
# ------------
# Retrieving results for city: menomonie
# ------------
# Retrieving results for city: hithadhoo
# ------------
# Retrieving results for city: iqaluit
# ------------
# Retrieving results for city: nanortalik
# ------------
# Retrieving results for city: ndele
# Missing field/result... skipping.
# ------------
# Retrieving results for city: rikitea
# ------------
# Retrieving results for city: jurm
# Missing field/result... skipping.
# ------------
# Retrieving results for city: hermanus
# ------------
# Retrieving results for city: bambous virieux
# ------------
# Retrieving results for city: hamilton
# ------------
# Retrieving results for city: sao joao da barra
# ------------
# Retrieving results for city: kvarkeno
# ------------
# Retrieving results for city: maldonado
# ------------
# Retrieving results for city: punta arenas
# ------------
# Retrieving results for city: tanout
# Missing field/result... skipping.
# ------------
# Retrieving results for city: quelimane
# ------------
# Retrieving results for city: arman
# Missing field/result... skipping.
# ------------
# Retrieving results for city: andenes
# ------------
# Retrieving results for city: bania
# ------------
# Retrieving results for city: arraial do cabo
# ------------
# Retrieving results for city: labrea
# ------------
# Retrieving results for city: port alfred
# ------------
# Retrieving results for city: kapoeta
# ------------
# Retrieving results for city: nhulunbuy
# ------------
# Retrieving results for city: fortuna
# ------------
# Retrieving results for city: galway
# ------------
# Retrieving results for city: kaeo
# ------------
# Retrieving results for city: ushuaia
# ------------
# Retrieving results for city: kapaa
# ------------
# Retrieving results for city: cape town
# ------------
# Retrieving results for city: hobart
# ------------
# Retrieving results for city: cidreira
# ------------
# Retrieving results for city: korla
# ------------
# Retrieving results for city: belmonte
# ------------
# Retrieving results for city: albany
# Missing field/result... skipping.
# ------------
# Retrieving results for city: krasnoselkup
# ------------
# Retrieving results for city: pinar del rio
# ------------
# Retrieving results for city: upernavik
# ------------
# Retrieving results for city: new norfolk
# ------------
# Retrieving results for city: vimperk
# ------------
# Retrieving results for city: hilo
# ------------
# Retrieving results for city: manzanillo
# ------------
# Retrieving results for city: kolpny
# Missing field/result... skipping.
# ------------
# Retrieving results for city: kupang
# ------------
# Retrieving results for city: lagoa
# ------------
# Retrieving results for city: alyangula
# ------------
# Retrieving results for city: tasiilaq
# ------------
# Retrieving results for city: kabarnet
# ------------
# Retrieving results for city: malanje
# ------------
# Retrieving results for city: kautokeino
# ------------
# Retrieving results for city: carnarvon
# ------------
# Retrieving results for city: sao felix do xingu
# ------------
# Retrieving results for city: lorengau
# ------------
# Retrieving results for city: bremerton
# ------------
# Retrieving results for city: opunake
# ------------
# Retrieving results for city: minatitlan
# ------------
# Retrieving results for city: east london
# ------------
# Retrieving results for city: qaanaaq
# ------------
# Retrieving results for city: gat
# ------------
# Retrieving results for city: kaitangata
# ------------
# Retrieving results for city: ust-nera
# ------------
# Retrieving results for city: port elizabeth
# ------------
# Retrieving results for city: moroto
# ------------
# Retrieving results for city: benxi
# ------------
# Retrieving results for city: kalamare
# Missing field/result... skipping.
# ------------
# Retrieving results for city: cherskiy
# ------------
# Retrieving results for city: shingu
# ------------
# Retrieving results for city: acapulco
# ------------
# Retrieving results for city: grand gaube
# ------------
# Retrieving results for city: altay
# ------------
# Retrieving results for city: kasongo
# ------------
# Retrieving results for city: jamestown
# ------------
# Retrieving results for city: severo-kurilsk
# ------------
# Retrieving results for city: inirida
# ------------
# Retrieving results for city: nagato
# ------------
# Retrieving results for city: khandyga
# ------------
# Retrieving results for city: sechura
# ------------
# Retrieving results for city: saint-pierre
# ------------
# Retrieving results for city: taoudenni
# Missing field/result... skipping.
# ------------
# Retrieving results for city: avarua
# ------------
# Retrieving results for city: esperance
# ------------
# Retrieving results for city: college
# ------------
# Retrieving results for city: virginia beach
# ------------
# Retrieving results for city: saint george
# ------------
# Retrieving results for city: sao filipe
# ------------
# Retrieving results for city: kanniyakumari
# ------------
# Retrieving results for city: abalak
# ------------
# Retrieving results for city: birjand
# ------------
# Retrieving results for city: voloshka
# Missing field/result... skipping.
# ------------
# Retrieving results for city: taltal
# ------------
# Retrieving results for city: faanui
# ------------
# Retrieving results for city: muscat
# ------------
# Retrieving results for city: malindi
# ------------
# Retrieving results for city: letlhakane
# ------------
# Retrieving results for city: vanimo
# ------------
# Retrieving results for city: tadine
# Missing field/result... skipping.
# ------------
# Retrieving results for city: margate
# ------------
# Retrieving results for city: jyvaskyla
# ------------
# Retrieving results for city: san quintin
# ------------
# Retrieving results for city: sur
# ------------
# Retrieving results for city: banda aceh
# ------------
# Retrieving results for city: gunnedah
# ------------
# Retrieving results for city: novoagansk
# Missing field/result... skipping.
# ------------
# Retrieving results for city: yaan
# Missing field/result... skipping.
# ------------
# Retrieving results for city: magadan
# ------------
# Retrieving results for city: seidu
# Missing field/result... skipping.
# ------------
# Retrieving results for city: cabo san lucas
# ------------
# Retrieving results for city: athabasca
# ------------
# Retrieving results for city: ancud
# ------------
# Retrieving results for city: khor
# ------------
# Retrieving results for city: antofagasta
# ------------
# Retrieving results for city: isilkul
# ------------
# Retrieving results for city: petropavlovsk-kamchatskiy
# ------------
# Retrieving results for city: kwekwe
# ------------
# Retrieving results for city: megali panayia
# ------------
# Retrieving results for city: arlit
# ------------
# Retrieving results for city: castro
# ------------
# Retrieving results for city: bengkulu
# ------------
# Retrieving results for city: puerto escondido
# ------------
# Retrieving results for city: zhigansk
# ------------
# Retrieving results for city: chuy
# ------------
# Retrieving results for city: georgetown
# ------------
# Retrieving results for city: thompson
# ------------
# Retrieving results for city: caconda
# Missing field/result... skipping.
# ------------
# Retrieving results for city: usinsk
# ------------
# Retrieving results for city: biak
# ------------
# Retrieving results for city: yellowknife
# ------------
# Retrieving results for city: sembakung
# Missing field/result... skipping.
# ------------
# Retrieving results for city: charlestown
# ------------
# Retrieving results for city: katsuura
# ------------
# Retrieving results for city: hami
# ------------
# Retrieving results for city: butaritari
# ------------
# Retrieving results for city: maniitsoq
# ------------
# Retrieving results for city: san cristobal
# ------------
# Retrieving results for city: srednekolymsk
# Missing field/result... skipping.
# ------------
# Retrieving results for city: ostrovnoy
# Missing field/result... skipping.
# ------------
# Retrieving results for city: lebu
# ------------
# Retrieving results for city: pohrebyshche
# ------------
# Retrieving results for city: salym
# ------------
# Retrieving results for city: torbay
# ------------
# Retrieving results for city: honningsvag
# ------------
# Retrieving results for city: mingyue
# ------------
# Retrieving results for city: mandalgovi
# ------------
# Retrieving results for city: mount isa
# ------------
# Retrieving results for city: khorramshahr
# ------------
# Retrieving results for city: clyde river
# ------------
# Retrieving results for city: borogontsy
# Missing field/result... skipping.
# ------------
# Retrieving results for city: bara
# Missing field/result... skipping.
# ------------
# Retrieving results for city: bandarbeyla
# ------------
# Retrieving results for city: chauk
# ------------
# Retrieving results for city: ivangorod
# ------------
# Retrieving results for city: pevek
# ------------
# Retrieving results for city: barrow
# ------------
# Retrieving results for city: tuktoyaktuk
# ------------
# Retrieving results for city: maragogi
# ------------
# Retrieving results for city: verkhnevilyuysk
# ------------
# Retrieving results for city: pak phanang
# ------------
# Retrieving results for city: namibe
# ------------
# Retrieving results for city: codrington
# ------------
# Retrieving results for city: ribeira grande
# ------------
# Retrieving results for city: kazachinskoye
# ------------
# Retrieving results for city: port hardy
# ------------
# Retrieving results for city: souillac
# ------------
# Retrieving results for city: elko
# Missing field/result... skipping.
# ------------
# Retrieving results for city: jalu
# ------------
# Retrieving results for city: galle
# ------------
# Retrieving results for city: chachapoyas
# ------------
# Retrieving results for city: mar del plata
# ------------
# Retrieving results for city: montepuez
# ------------
# Retrieving results for city: caravelas
# ------------
# Retrieving results for city: san juan
# ------------
# Retrieving results for city: sobolevo
# Missing field/result... skipping.
# ------------
# Retrieving results for city: bathsheba
# ------------
# Retrieving results for city: kenai
# ------------
# Retrieving results for city: parrita
# ------------
# Retrieving results for city: geraldton
# ------------
# Retrieving results for city: hailar
# ------------
# Retrieving results for city: huayucachi
# ------------
# Retrieving results for city: smithers
# ------------
# Retrieving results for city: chimbote
# ------------
# Retrieving results for city: mogadishu
# ------------
# Retrieving results for city: tamworth
# ------------
# Retrieving results for city: mayumba
# ------------
# Retrieving results for city: nador
# ------------
# Retrieving results for city: bonavista
# ------------
# Retrieving results for city: coahuayana
# ------------
# Retrieving results for city: san luis
# ------------
# Retrieving results for city: yerbogachen
# Missing field/result... skipping.
# ------------
# Retrieving results for city: seoul
# ------------
# Retrieving results for city: dali
# ------------
# Retrieving results for city: ponta do sol
# ------------
# Retrieving results for city: umea
# ------------
# Retrieving results for city: rakaia
# ------------
# Retrieving results for city: port lincoln
# ------------
# Retrieving results for city: deder
# ------------
# Retrieving results for city: bougouni
# ------------
# Retrieving results for city: hualmay
# ------------
# Retrieving results for city: schwarzenbek
# ------------
# Retrieving results for city: vaini
# ------------
# Retrieving results for city: los llanos de aridane
# ------------
# Retrieving results for city: matagami
# ------------
# Retrieving results for city: liverpool
# ------------
# Retrieving results for city: husavik
# ------------
# Retrieving results for city: ciudad bolivar
# ------------
# Retrieving results for city: tubuala
# Missing field/result... skipping.
# ------------
# Retrieving results for city: mont-de-marsan
# ------------
# Retrieving results for city: vestmannaeyjar
# ------------
# Retrieving results for city: andilamena
# ------------
# Retrieving results for city: pathein
# ------------
# Retrieving results for city: port hedland
# ------------
# Retrieving results for city: rantauprapat
# ------------
# Retrieving results for city: djibo
# ------------
# Retrieving results for city: churu
# ------------
# Retrieving results for city: demirci
# ------------
# Retrieving results for city: yulara
# ------------
# Retrieving results for city: rognan
# ------------
# Retrieving results for city: lavrentiya
# Missing field/result... skipping.
# ------------
# Retrieving results for city: estevan
# ------------
# Retrieving results for city: quartucciu
# ------------
# Retrieving results for city: saskylakh
# Missing field/result... skipping.
# ------------
# Retrieving results for city: komsomolskiy
# ------------
# Retrieving results for city: le port
# ------------
# Retrieving results for city: ahipara
# ------------
# Retrieving results for city: hasaki
# ------------
# Retrieving results for city: cleethorpes
# ------------
# Retrieving results for city: uaua
# ------------
# Retrieving results for city: abu road
# ------------
# Retrieving results for city: coihaique
# ------------
# Retrieving results for city: ola
# Missing field/result... skipping.
# ------------
# Retrieving results for city: klaksvik
# ------------
# Retrieving results for city: sorong
# ------------
# Retrieving results for city: kharp
# ------------
# Retrieving results for city: toumodi
# ------------
# Retrieving results for city: dingle
# ------------
# Retrieving results for city: hurricane
# ------------
# Retrieving results for city: beringovskiy
# Missing field/result... skipping.
# ------------
# Retrieving results for city: dasoguz
# ------------
# Retrieving results for city: bauchi
# Missing field/result... skipping.
# ------------
# Retrieving results for city: te anau
# ------------
# Retrieving results for city: biltine
# ------------
# Retrieving results for city: bogotol
# ------------
# Retrieving results for city: strezhevoy
# ------------
# Retrieving results for city: flinders
# ------------
# Retrieving results for city: tchollire
# ------------
# Retrieving results for city: talnakh
# ------------
# Retrieving results for city: matay
# ------------
# Retrieving results for city: katwijk
# ------------
# Retrieving results for city: manggar
# ------------
# Retrieving results for city: bolbec
# ------------
# Retrieving results for city: khatanga
# ------------
# Retrieving results for city: imeni poliny osipenko
# ------------
# Retrieving results for city: kem
# ------------
# Retrieving results for city: omboue
# ------------
# Retrieving results for city: dikson
# Missing field/result... skipping.
# ------------
# Retrieving results for city: naron
# ------------
# Retrieving results for city: pauini
# ------------
# Retrieving results for city: saint anthony
# ------------
# Retrieving results for city: chumikan
# ------------
# Retrieving results for city: saldanha
# ------------
# Retrieving results for city: narsaq
# ------------
# Retrieving results for city: chabahar
# ------------
# Retrieving results for city: qaqortoq
# ------------
# Retrieving results for city: oneida
# ------------
# Retrieving results for city: tilichiki
# Missing field/result... skipping.
# ------------
# Retrieving results for city: tuatapere
# ------------
# Retrieving results for city: paracuru
# ------------
# Retrieving results for city: challapata
# ------------
# Retrieving results for city: asbe teferi
# ------------
# Retrieving results for city: naze
# ------------
# Retrieving results for city: hovd
# ------------
# Retrieving results for city: baykit
# Missing field/result... skipping.
# ------------
# Retrieving results for city: wanning
# ------------
# Retrieving results for city: victoria
# ------------
# Retrieving results for city: salinopolis
# ------------
# Retrieving results for city: ammon
# ------------
# Retrieving results for city: presidente epitacio
# ------------
# Retrieving results for city: forestville
# ------------
# Retrieving results for city: maxixe
# ------------
# Retrieving results for city: muirkirk
# ------------
# Retrieving results for city: haines junction
# ------------
# Retrieving results for city: verkhneyarkeyevo
# ------------
# Retrieving results for city: kirakira
# ------------
# Retrieving results for city: doctor juan leon mallorquin
# ------------
# Retrieving results for city: sept-iles
# ------------
# Retrieving results for city: kurilsk
# ------------
# Retrieving results for city: saint-joseph
# ------------
# Retrieving results for city: effingham
# ------------
# Retrieving results for city: amargosa
# ------------
# Retrieving results for city: nautla
# ------------
# Retrieving results for city: maceio
# ------------
# Retrieving results for city: bubaque
# ------------
# Retrieving results for city: vila velha
# ------------
# Retrieving results for city: saint-philippe
# ------------
# Retrieving results for city: itarema
# ------------
# Retrieving results for city: monrovia
# ------------
# Retrieving results for city: mahebourg
# ------------
# Retrieving results for city: rapid valley
# ------------
# Retrieving results for city: provideniya
# Missing field/result... skipping.
# ------------
# Retrieving results for city: kisangani
# ------------
# Retrieving results for city: berlevag
# ------------
# Retrieving results for city: tiksi
# ------------
# Retrieving results for city: chapais
# ------------
# Retrieving results for city: kavieng
# ------------
# Retrieving results for city: corinto
# ------------
# Retrieving results for city: svetlogorsk
# ------------
# Retrieving results for city: senanga
# ------------
# Retrieving results for city: asau
# ------------
# Retrieving results for city: alugan
# ------------
# Retrieving results for city: pacific grove
# ------------
# Retrieving results for city: sitka
# ------------
# Retrieving results for city: san jeronimo
# ------------
# Retrieving results for city: okhotsk
# Missing field/result... skipping.
# ------------
# Retrieving results for city: medicine hat
# ------------
# Retrieving results for city: karratha
# ------------
# Retrieving results for city: la palma
# ------------
# Retrieving results for city: sonder bjert
# ------------
# Retrieving results for city: shellbrook
# ------------
# Retrieving results for city: rawson
# ------------
# Retrieving results for city: muriti
# Missing field/result... skipping.
# ------------
# Retrieving results for city: vao
# ------------
# Retrieving results for city: porosozero
# ------------
# Retrieving results for city: mufumbwe
# Missing field/result... skipping.
# ------------
# Retrieving results for city: mackenzie
# ------------
# Retrieving results for city: vila franca do campo
# ------------
# Retrieving results for city: miandrivazo
# ------------
# Retrieving results for city: namatanai
# ------------
# Retrieving results for city: dharchula
# ------------
# Retrieving results for city: pilar
# ------------
# Retrieving results for city: boyolangu
# ------------
# Retrieving results for city: norman wells
# ------------
# Retrieving results for city: avera
# Missing field/result... skipping.
# ------------
# Retrieving results for city: kavaratti
# ------------
# Retrieving results for city: isiolo
# ------------
# Retrieving results for city: hay river
# ------------
# Retrieving results for city: tual
# ------------
# Retrieving results for city: stepnyak
# Missing field/result... skipping.
# ------------
# Retrieving results for city: almaznyy
# Missing field/result... skipping.
# ------------
# Retrieving results for city: riyadh
# ------------
# Retrieving results for city: marawi
# ------------
# Retrieving results for city: nikita
# ------------
# Retrieving results for city: auki
# ------------
# Retrieving results for city: olafsvik
# ------------
# Retrieving results for city: karasjok
# ------------
# Retrieving results for city: kuching
# ------------
# Retrieving results for city: gordeyevka
# Missing field/result... skipping.
# ------------
# Retrieving results for city: atar
# ------------
# Retrieving results for city: kallithea
# ------------
# Retrieving results for city: det udom
# ------------
# Retrieving results for city: christchurch
# ------------
# Retrieving results for city: ribeira brava
# ------------
# Retrieving results for city: dana point
# ------------
# Retrieving results for city: berbera
# ------------
# Retrieving results for city: carutapera
# ------------
# Retrieving results for city: dudinka
# ------------
# Retrieving results for city: la ronge
# ------------
# Retrieving results for city: chifeng
# ------------
# Retrieving results for city: muisne
# ------------
# Retrieving results for city: vanavara
# Missing field/result... skipping.
# ------------
# Retrieving results for city: jiexiu
# ------------
# Retrieving results for city: prince rupert
# ------------
# Retrieving results for city: leirvik
# ------------
# Retrieving results for city: soe
# ------------
# Retrieving results for city: chokurdakh
# Missing field/result... skipping.
# ------------
# Retrieving results for city: longyearbyen
# ------------
# Retrieving results for city: san benito
# Missing field/result... skipping.
# ------------
# Retrieving results for city: gravelbourg
# ------------
# Retrieving results for city: balkanabat
# ------------
# Retrieving results for city: wewak
# ------------
# Retrieving results for city: caibarien
# ------------
# Retrieving results for city: lahat
# ------------
# Retrieving results for city: buraydah
# ------------
# Retrieving results for city: coquimbo
# ------------
# Retrieving results for city: guia de isora
# ------------
# Retrieving results for city: hirara
# ------------
# Retrieving results for city: balestrand
# ------------
# Retrieving results for city: najran
# ------------
# Retrieving results for city: lasa
# ------------
# Retrieving results for city: tommot
# ------------
# Retrieving results for city: port macquarie
# ------------
# Retrieving results for city: mbandaka
# ------------
# Retrieving results for city: dera bugti
# ------------
# Retrieving results for city: miquelon
# ------------
# Retrieving results for city: voyvozh
# ------------
# Retrieving results for city: guerrero negro
# ------------
# Retrieving results for city: conceicao do araguaia
# ------------
# Retrieving results for city: alofi
# ------------
# Retrieving results for city: faya
# ------------
# Retrieving results for city: aklavik
# ------------
# Retrieving results for city: bahile
# ------------
# Retrieving results for city: balikpapan
# ------------
# Retrieving results for city: humen
# ------------
# Retrieving results for city: palmas bellas
# ------------
# Retrieving results for city: bat yam
# ------------
# Retrieving results for city: mashhad
# ------------
# Retrieving results for city: moron
# ------------
# Retrieving results for city: oussouye
# ------------
# Retrieving results for city: ulaangom
# ------------
# Retrieving results for city: miracema do tocantins
# ------------
# Retrieving results for city: meulaboh
# ------------
# Retrieving results for city: turukhansk
# ------------
# Retrieving results for city: fort-shevchenko
# ------------
# Retrieving results for city: grindavik
# ------------
# Retrieving results for city: brownsville
# ------------
# Retrieving results for city: puerto quijarro
# ------------
# Retrieving results for city: perth
# ------------
# Retrieving results for city: colatina
# ------------
# Retrieving results for city: phalombe
# ------------
# Retrieving results for city: sao luiz gonzaga
# ------------
# Retrieving results for city: gornopravdinsk
# ------------
# Retrieving results for city: rio branco do sul
# ------------
# Retrieving results for city: verkhoyansk
# Missing field/result... skipping.
# ------------
# Retrieving results for city: fairbanks
# ------------
# Retrieving results for city: rairangpur
# ------------
# Retrieving results for city: donskoy
# ------------
# Retrieving results for city: bath
# ------------
# Retrieving results for city: zeya
# ------------
# Retrieving results for city: labuan
# ------------
# Retrieving results for city: sola
# ------------
# Retrieving results for city: flin flon
# ------------
# Retrieving results for city: nantucket
# ------------
# Retrieving results for city: san ramon
# ------------
# Retrieving results for city: watsa
# ------------
# Retrieving results for city: siuri
# ------------
# Retrieving results for city: myitkyina
# ------------
# Retrieving results for city: esso
# ------------
# Retrieving results for city: teguise
# ------------
# Retrieving results for city: lompoc
# ------------
# Retrieving results for city: makakilo city
# ------------
# Retrieving results for city: tirthahalli
# ------------
# Retrieving results for city: havre-saint-pierre
# ------------
# Retrieving results for city: wencheng
# ------------
# Retrieving results for city: grand-santi
# ------------
# Retrieving results for city: mountain home
# ------------
# Retrieving results for city: kingman
# ------------
# Retrieving results for city: valparaiso
# ------------
# Retrieving results for city: ewa beach
# ------------
# Retrieving results for city: mikun
# ------------
# Retrieving results for city: nizhniy kuranakh
# ------------
# Retrieving results for city: dickinson
# ------------
# Retrieving results for city: batemans bay
# ------------
# Retrieving results for city: gryazovets
# ------------
# Retrieving results for city: ormara
# ------------
# Retrieving results for city: matriz de camaragibe
# ------------
# Retrieving results for city: bucerias
# ------------
# Retrieving results for city: muros
# ------------
# Retrieving results for city: russell
# ------------
# Retrieving results for city: dergachi
# Missing field/result... skipping.
# ------------
# Retrieving results for city: saint-augustin
# Missing field/result... skipping.
# ------------
# Retrieving results for city: nome
# ------------
# Retrieving results for city: chuguyevka
# ------------
# Retrieving results for city: huilong
# ------------
# Retrieving results for city: bodden town
# ------------
# Retrieving results for city: awjilah
# ------------
# Retrieving results for city: pineville
# ------------
# Retrieving results for city: ranghulu
# ------------
# Retrieving results for city: vicuna
# ------------
# Retrieving results for city: singapore
# ------------
# Retrieving results for city: srandakan
# ------------
# Retrieving results for city: isangel
# ------------
# Retrieving results for city: champerico
# ------------
# Retrieving results for city: cayenne
# ------------
# Retrieving results for city: hutchinson
# ------------
# Retrieving results for city: swan hill
# ------------
# Retrieving results for city: porto velho
# ------------
# Retrieving results for city: pokrovskoye
# ------------
# Retrieving results for city: puyang
# ------------
# Retrieving results for city: constitucion
# ------------
# Retrieving results for city: college station
# ------------
# Retrieving results for city: kjollefjord
# ------------
# Retrieving results for city: brae
# ------------
# Retrieving results for city: praya
# ------------
# Retrieving results for city: ballina
# ------------
# Retrieving results for city: novo aripuana
# ------------
# Retrieving results for city: edea
# ------------
# Retrieving results for city: kahului
# ------------
# Retrieving results for city: nicolas bravo
# Missing field/result... skipping.
# ------------
# Retrieving results for city: gizo
# ------------
# Retrieving results for city: sussex
# ------------
# Retrieving results for city: eydhafushi
# ------------
# Retrieving results for city: roald
# ------------
# Retrieving results for city: sonoita
# ------------
# Retrieving results for city: lima
# ------------
# Retrieving results for city: axim
# ------------
# Retrieving results for city: playas
# ------------
# Retrieving results for city: san francisco
# ------------
# Retrieving results for city: pachino
# ------------
# Retrieving results for city: spanish town
# ------------
# Retrieving results for city: manjacaze
# ------------
# Retrieving results for city: cedral
# ------------
# Retrieving results for city: zelenoborskiy
# ------------
# Retrieving results for city: leicester
# ------------
# Retrieving results for city: san patricio
# ------------
# Retrieving results for city: namwala
# ------------
# Retrieving results for city: assiniboia
# ------------
# Retrieving results for city: agirish
# Missing field/result... skipping.
# ------------
# Retrieving results for city: viedma
# ------------
# Retrieving results for city: wheeling
# ------------
# Retrieving results for city: vuktyl
# ------------
# Retrieving results for city: ha giang
# ------------
# Retrieving results for city: vrangel
# ------------
# Retrieving results for city: tucuma
# Missing field/result... skipping.
# ------------
# Retrieving results for city: kogon
# ------------
# Retrieving results for city: ugoofaaru
# ------------
# Retrieving results for city: deputatskiy
# ------------
# Retrieving results for city: verkhnetulomskiy
# ------------
# Retrieving results for city: ilulissat
# ------------
# Retrieving results for city: vostok
# Missing field/result... skipping.
# ------------
# Retrieving results for city: kununurra
# ------------
# Retrieving results for city: bumba
# ------------
# Retrieving results for city: gerash
# ------------
# Retrieving results for city: cascais
# ------------
# Retrieving results for city: ughelli
# ------------
# Retrieving results for city: san isidro
# ------------
# Retrieving results for city: puerto madryn
# ------------
# Retrieving results for city: yanam
# ------------
# Retrieving results for city: mabaruma
# ------------
# Retrieving results for city: paciran
# ------------
# Retrieving results for city: abengourou
# ------------
# Retrieving results for city: coos bay
# ------------
# Retrieving results for city: amagi
# ------------
# Retrieving results for city: areosa
# ------------
# Retrieving results for city: bilibino
# ------------
# Retrieving results for city: rocha
# ------------
# Retrieving results for city: caborca
# ------------
# Retrieving results for city: porto santo
# ------------
# Retrieving results for city: jaciara
# ------------
# Retrieving results for city: caraz
# ------------
# Retrieving results for city: cockburn town
# ------------
# Retrieving results for city: vaitape
# ------------
# Retrieving results for city: fairview
# ------------
# Retrieving results for city: rovaniemi
# ------------
# Retrieving results for city: alice town
# ------------
# Retrieving results for city: nouadhibou
# ------------
# Retrieving results for city: sadovoye
# ------------
# Retrieving results for city: krosno odrzanskie
# ------------
# Retrieving results for city: batticaloa
# ------------
# Retrieving results for city: hellvik
# ------------
# Retrieving results for city: lianran
# ------------
# Retrieving results for city: altamira
# ------------
# Retrieving results for city: kabompo
# ------------
# Retrieving results for city: kulhudhuffushi
# ------------
# Retrieving results for city: fevik
# ------------
# Retrieving results for city: kruisfontein
# ------------
# Retrieving results for city: itoman
# ------------
# Retrieving results for city: abatskoye
# ------------
# Retrieving results for city: khilok
# ------------
# Retrieving results for city: takayama
# ------------
# Retrieving results for city: ust-kut
# ------------
# Retrieving results for city: santo antonio de jesus
# ------------
# Retrieving results for city: manono
# ------------
# Retrieving results for city: abha
# ------------
# Retrieving results for city: nicoya
# ------------
# Retrieving results for city: portland
# ------------
# Retrieving results for city: nijar
# ------------
# Retrieving results for city: gamba
# Missing field/result... skipping.
# ------------
# Retrieving results for city: abu samrah
# Missing field/result... skipping.
# ------------
# Retrieving results for city: mizdah
# ------------
# Retrieving results for city: nouakchott
# ------------
# Retrieving results for city: beitbridge
# ------------
# Retrieving results for city: orneta
# ------------
# Retrieving results for city: rakitnoye
# ------------
# Retrieving results for city: mitsamiouli
# ------------
# Retrieving results for city: salalah
# ------------
# Retrieving results for city: bundaberg
# ------------
# Retrieving results for city: aykhal
# Missing field/result... skipping.
# ------------
# Retrieving results for city: osoyoos
# ------------
# Retrieving results for city: am timan
# ------------
#             City Country      Lat       Lng  \
# 0         kodiak      US  57.7900 -152.4072
# 1    puebloviejo      CO  10.9938  -74.2844
# 2      busselton      AU -33.6500  115.3333
# 3     san andres      CO  12.5847  -81.7006
# 4          bytow      PL  54.1706   17.4919
# ..           ...     ...      ...       ...
# 580      salalah      OM  17.0151   54.0924
# 581    bundaberg      AU -24.8500  152.3500
# 582       aykhal      RU  66.0000  111.5000
# 583      osoyoos      CA  49.0331 -119.4524
# 584     am timan      TD  11.0297   20.2827
#
#                                         Hotel Name
# 0    Best Western Kodiak Inn And Convention Center
# 1                               The Journey Hostel
# 2                          Observatory Guest House
# 3                               Hotel Arena Blanca
# 4                                 Centrum UŁAN SPA
# ..                                             ...
# 580       HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# 581                                 Takalvan Motel
# 582
# 583                         Watermark Beach Resort
# 584                   Palais du chef Canton Salamt
#
# [583 rows x 5 columns]

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
! jupyter nbextension enable --py --sys-prefix gmaps
! jupyter nbextension enable --py gmaps
! jupyter nbextension enable --py widgetsnbextension
